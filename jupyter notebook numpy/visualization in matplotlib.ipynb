# %%
import pandas as pd

# %%
air = pd.read_csv("Admission_Predict.csv")

# %%
print(air.head())
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
import matplotlib.pyplot as plt

# %%
# Create a figure and axis
# fig, ax = plt.subplots()

# Show the plot
# plt.show()

# Save the figure
# plt.savefig('plot.png')

# %%
plt.plot(air['Chance of Admit '],air["GRE Score"])
plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Plot Title')
plt.grid(True)

# %%
plt.scatter(air['Chance of Admit '],air["GRE Score"],  c='blue', alpha=0.5)

# %%
plt.hist(air['Chance of Admit '], density="True",color= 'skyblue', edgecolor='black')
# Out:
# (array([0.27777778, 0.55555556, 0.79365079, 1.26984127, 1.94444444,
#         2.34126984, 3.13492063, 2.02380952, 1.58730159, 1.94444444]),
#  array([0.34 , 0.403, 0.466, 0.529, 0.592, 0.655, 0.718, 0.781, 0.844,
#         0.907, 0.97 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(air["GRE Score"], height=0.8, width=0.8, color='blue')
# Out:
# <BarContainer object of 400 artists>

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.scatter(air['Chance of Admit '],air["GRE Score"], color='red', )
ax2.hist(air['Chance of Admit '], color='skyblue', edgecolor='black')
# Out:
# (array([ 7., 14., 20., 32., 49., 59., 79., 51., 40., 49.]),
#  array([0.34 , 0.403, 0.466, 0.529, 0.592, 0.655, 0.718, 0.781, 0.844,
#         0.907, 0.97 ]),
#  <BarContainer object of 10 artists>)

# %%
air['Chance of Admit '].describe()
# Out:
# count    400.000000
# mean       0.724350
# std        0.142609
# min        0.340000
# 25%        0.640000
# 50%        0.730000
# 75%        0.830000
# max        0.970000
# Name: Chance of Admit , dtype: float64

# %% [markdown]
# ### Line plot

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create figure and axis
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='sin(x)', color='blue', linewidth=2)
plt.title('Sine Wave')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### scatter plot

# %%
## scatter plot in matplotlib
x = np.random.rand(100)
y = np.random.rand(100)
# colors = np.random.rand(100)
sizes = 1000 * np.random.rand(100)

plt.figure(figsize=(10, 6))
plt.scatter(x, y,  s=sizes, alpha=0.5)
plt.title('Scatter Plot')
plt.xlabel('X')
plt.ylabel('Y')
plt.colorbar()
plt.show()

# %% [markdown]
# ## BAr plot

# %%
### Bar plot in matpolt

categories = ['A', 'B', 'C', 'D']
values = [10, 20, 15, 25]

plt.figure(figsize=(10, 6))
plt.bar(categories, values, color='skyblue')
plt.title('Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 categories = ['A', 'B', 'C', 'D']
#       2 values = [10, 20, 15, 25]
# ----> 4 plt.figure(figsize=(10, 6))
#       5 plt.bar(categories, values, color='skyblue')
#       6 plt.title('Bar Plot')
#
# NameError: name 'plt' is not defined

# %%
# Create subplots
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Plot 1
axes[0, 0].plot(x, np.sin(x))
axes[0, 0].set_title('Sine')

# Plot 2
axes[0, 1].plot(x, np.cos(x))
axes[0, 1].set_title('Cosine')

# Plot 3
axes[1, 0].plot(x, np.tan(x))
axes[1, 0].set_title('Tangent')

# Plot 4
axes[1, 1].plot(x, np.exp(x))
axes[1, 1].set_title('Exponential')

plt.tight_layout()
plt.show()

# %%
## subplots in matplotlib

groups = ["group_1","group_2","group_3"]
values = [5,50,100]

fig, axis = plt.subplots(2,3 , figsize=(9,3))
axis[0,0].bar(groups,values, color='purple')
axis[0,0].set_title('Bar Chart')

axis[0,1].hist(values)
axis[0,1].set_title('Histogram')

axes[0,2].plot(groups,values)
axes[0,2].set_title("plot")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 11
#       8 axis[0,1].hist(values)
#       9 axis[0,1].set_title('Histogram')
# ---> 11 axes[0,2].plot(groups,values)
#      12 axes[0,2].set_title("plot")
#
# IndexError: index 2 is out of bounds for axis 1 with size 2
